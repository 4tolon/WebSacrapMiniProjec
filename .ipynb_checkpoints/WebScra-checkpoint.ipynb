# %%
# El mantra de las visualizaciones
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
opciones=Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')              # incognito

# %%
precio = []
producto = []
photo = []
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver,  options = opciones)
url = 'https://www.intimissimi.com/es/'
driver.get(url)
driver.implicitly_wait(4) 
driver.find_element_by_css_selector("#cc-approve-button-thissite").click()


driver.get(f"https://www.intimissimi.com/es/mujer/sujetadores/?start={0*24}&sz=24")
#lista.append(driver.find_element_by_css_selector(f"#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child{0+1} > div > a").text)

precio = []
producto = []
photo = []
colors = []
for j in range(20):
    driver.get(f"https://www.intimissimi.com/es/mujer/sujetadores/?start={j*24}&sz=24")
    for i in range(1,25):
            try:
                producto.append(driver.find_element_by_css_selector(f"#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child({i}) > div > a > div.tile-body > div.product-tile__name > div > span").text)
                precio.append(driver.find_element_by_css_selector(f"#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child({i}) > div > a > div.tile-body > div.price-container > div > span > span > span.value.dark").text)
                try:
                    colors.append(driver.find_element_by_css_selector(f"#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child({i}) > div > a > div.tile-body > div.tile-colors > div.cell.color-swatches > div > span.small.light.text-darkish-gray.plp-swatch").text)
                except:
                    colors.append('1 colores')
                photo.append(driver.find_element_by_css_selector(f'#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child({i}) > div > a > div.image-container > section > div > div > img.tile-image.tile-image-carousel.slick-slide.slick-current.slick-active').get_attribute("src"))
            except:
                precio.append('None')
                producto.append('None')
                photo.append('None')



#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child(1) > div > a > div.tile-body > div.tile-colors > div.cell.color-swatches > div > span.small.light.text-darkish-gray.plp-swatch
# Out:
# /tmp/ipykernel_1178/1645435868.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver,  options = opciones)
# /tmp/ipykernel_1178/1645435868.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#cc-approve-button-thissite").click()
# /tmp/ipykernel_1178/1645435868.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   producto.append(driver.find_element_by_css_selector(f"#product-search-results > div:nth-child(2) > div:nth-child(2) > div > div:nth-child({i}) > div > a > div.tile-body > div.product-tile__name > div > span").text)
# /tmp/ipykernel_1178/1645435868.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
len(precio)
# Out:
# 422

# %%
precio
# Out:
# ['€ 29,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 27,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 19,90',
#  '€ 35,90',
#  '€ 35,90',
#  '€ 19,90',
#  '€ 35,90',
#  '€ 35,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 19,90',
#  '€ 35,90',
#  '€ 39,90',
#  '€ 35,90',
#  '€ 29,90',
#  '€ 27,90',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 19,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 39,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 19,90',
#  '€ 35,90',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 25,90',
#  '€ 35,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 5,90',
#  'None',
#  '€ 19,90',
#  '€ 27,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 29,90',
#  '€ 35,90',
#  '€ 4,00',
#  'None',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 19,90',
#  '€ 25,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 25,90',
#  '€ 19,90',
#  '€ 25,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 19,90',
#  '€ 29,90',
#  '€ 29,90',
#  '€ 27,90',
# ...

# %%
producto
# Out:
# ['Sujetador Balconette Elena de Encaje',
#  'Sujetador Triangular Sexy Dot Com',
#  'Sujetador Balconette Sexy Dot Com',
#  "Sujetador Carioca Silhouette D'Amour",
#  'Sujetador Super Push-Up Gioia Forever Macramè',
#  'Sujetador Gioia Super Push-Up de Microfibra',
#  'Sujetador Balconette Elena de Encaje',
#  'Sujetador Carioca Sexy Dot Com',
#  'Sujetador Super Push-Up Gioia Pretty Flowers',
#  'Sujetador Triangular Tiziana de Algodón',
#  "Sujetador Push-up Fabiola Silhouette D'Amour",
#  'Sujetador Balconette Sofia Pretty Iconic',
#  'Sujetador Triangular Tiziana de Algodón',
#  "Sujetador Super Push-Up Mia Let's Shine",
#  "Sujetador Balconette Sofia Silhouette D'Amour",
#  'Sujetador Balconette Elena de Encaje',
#  'Sujetador Balconette Sofia de Encaje',
#  'Sujetador Super Push-Up Gioia Pretty Flowers',
#  'Sujetador Triangular Lara de Algodón',
#  'Sujetador Balconette Sofia Romantic Life',
#  'Sujetador Balconette Sofia Pretty Flowers',
# ...

# %%
colors
# Out:
# ['4 Colores',
#  '2 Colores',
#  '',
#  '2 Colores',
#  '2 Colores',
#  '4 Colores',
#  '4 Colores',
#  '',
#  '5 Colores',
#  '14 Colores',
#  '2 Colores',
#  '',
#  '14 Colores',
#  '',
#  '2 Colores',
#  '4 Colores',
#  '7 Colores',
#  '5 Colores',
#  '9 Colores',
#  '2 Colores',
#  '5 Colores',
#  '2 Colores',
#  '',
#  '6 Colores',
#  '4 Colores',
#  '5 Colores',
#  '5 Colores',
#  '5 Colores',
#  '7 Colores',
#  '9 Colores',
#  '5 Colores',
#  '5 Colores',
#  '5 Colores',
#  '14 Colores',
#  '4 Colores',
#  '',
#  '7 Colores',
#  '',
#  '2 Colores',
#  '5 Colores',
#  '3 Colores',
#  '5 Colores',
#  '14 Colores',
#  '',
#  '5 Colores',
#  '14 Colores',
#  '2 Colores',
#  '',
#  '5 Colores',
#  '5 Colores',
#  '4 Colores',
#  '2 Colores',
#  '2 Colores',
#  '3 Colores',
#  '',
#  '2 Colores',
#  '5 Colores',
#  '5 Colores',
#  '4 Colores',
#  '5 Colores',
#  '3 Colores',
#  '4 Colores',
#  '14 Colores',
#  '3 Colores',
#  '',
#  '3 Colores',
#  '5 Colores',
#  '2 Colores',
# ...

# %%
len(colors)
# Out:
# 388

# %%
photo
# Out:
# ['https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwd28b7974/images/RID96L019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw3b5097d3/images/RSD2443019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw0bc7c6f8/images/RBD2443019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwe9b7104f/images/RBD24429888-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwbf833403/images/RPS1433019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw013293eb/images/RPS50B019-M.jpg?sw=400&sfrm=jpeg',
# ...

# %%
intimissimi = pd.DataFrame()

# %%
intimissimi['producto'] = producto
intimissimi = intimissimi[intimissimi['producto'] != 'None']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1178/2427735183.py in <module>
# ----> 1 intimissimi['producto'] = producto
#       2 intimissimi = intimissimi[intimissimi['producto'] != 'None']
#       3 intimissimi
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ...

# %%
intimissimi
# Out:
#                                               producto
# 0                 Sujetador Balconette Elena de Encaje
# 1                    Sujetador Triangular Sexy Dot Com
# 2                    Sujetador Balconette Sexy Dot Com
# 3                 Sujetador Carioca Silhouette D'Amour
# 4        Sujetador Super Push-Up Gioia Forever Macramè
# ..                                                 ...
# 397        Sujetador Balconette Giorgia Pretty Flowers
# 398                Sujetador Laura Banda en Microfibra
# 399  Sujetador Triangular Lara de Microfibra Ultral...
# 400   Sujetador Push-Up Sweet en Microfibra Bellissima
# 401             Sujetador Triangular de Encaje Tiziana
#
# [388 rows x 1 columns]

# %%
intimissimi['colors'] = colors
# Out:
# /tmp/ipykernel_1178/3648664911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intimissimi['colors'] = colors

# %%
intimissimi
# Out:
#                                               producto     colors
# 0                 Sujetador Balconette Elena de Encaje  4 Colores
# 1                    Sujetador Triangular Sexy Dot Com  2 Colores
# 2                    Sujetador Balconette Sexy Dot Com
# 3                 Sujetador Carioca Silhouette D'Amour  2 Colores
# 4        Sujetador Super Push-Up Gioia Forever Macramè  2 Colores
# ..                                                 ...        ...
# 397        Sujetador Balconette Giorgia Pretty Flowers  3 Colores
# 398                Sujetador Laura Banda en Microfibra  5 Colores
# 399  Sujetador Triangular Lara de Microfibra Ultral...  4 Colores
# 400   Sujetador Push-Up Sweet en Microfibra Bellissima  5 Colores
# 401             Sujetador Triangular de Encaje Tiziana  6 Colores
#
# [388 rows x 2 columns]

# %%
intimissimi1 = pd.DataFrame()
intimissimi1['precio'] = precio
intimissimi1 = intimissimi1[intimissimi1['precio'] != 'None']

# %%
intimissimi1
# Out:
#       precio
# 0    € 29,90
# 1    € 29,90
# 2    € 29,90
# 3    € 29,90
# 4    € 35,90
# ..       ...
# 397  € 39,90
# 398  € 29,90
# 399  € 27,90
# 400  € 19,90
# 401  € 27,90
#
# [388 rows x 1 columns]

# %%
len(photo)
# Out:
# 408

# %%
photo
# Out:
# ['https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwd28b7974/images/RID96L019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw3b5097d3/images/RSD2443019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw0bc7c6f8/images/RBD2443019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwe9b7104f/images/RBD24429888-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dwbf833403/images/RPS1433019-M.jpg?sw=400&sfrm=jpeg',
#  'https://www.intimissimi.com/dw/image/v2/BHHR_PRD/on/demandware.static/-/Sites-INT_EC_COM/default/dw013293eb/images/RPS50B019-M.jpg?sw=400&sfrm=jpeg',
# ...

# %%
intimissimi['precio'] = intimissimi1['precio']
# Out:
# /tmp/ipykernel_1178/2582084560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intimissimi['precio'] = intimissimi1['precio']

# %%
intimissimi
# Out:
#                                               producto     colors   precio
# 0                 Sujetador Balconette Elena de Encaje  4 Colores  € 29,90
# 1                    Sujetador Triangular Sexy Dot Com  2 Colores  € 29,90
# 2                    Sujetador Balconette Sexy Dot Com             € 29,90
# 3                 Sujetador Carioca Silhouette D'Amour  2 Colores  € 29,90
# 4        Sujetador Super Push-Up Gioia Forever Macramè  2 Colores  € 35,90
# ..                                                 ...        ...      ...
# 397        Sujetador Balconette Giorgia Pretty Flowers  3 Colores  € 39,90
# 398                Sujetador Laura Banda en Microfibra  5 Colores  € 29,90
# 399  Sujetador Triangular Lara de Microfibra Ultral...  4 Colores  € 27,90
# 400   Sujetador Push-Up Sweet en Microfibra Bellissima  5 Colores  € 19,90
# 401             Sujetador Triangular de Encaje Tiziana  6 Colores  € 27,90
#
# [388 rows x 3 columns]

# %%
intimissimi.to_csv('sujetas.csv', index=False)

# %%
intimissimi2 = pd.DataFrame()
intimissimi2['photo_link'] = photo

# %%
intimissimi2['photo_link'] = intimissimi2[intimissimi2['photo_link'] != 'None']

# %%
intimissimi2.dropna()
# Out:
#                                             photo_link
# 0    https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 1    https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 2    https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 3    https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 4    https://www.intimissimi.com/dw/image/v2/BHHR_P...
# ..                                                 ...
# 383  https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 384  https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 385  https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 386  https://www.intimissimi.com/dw/image/v2/BHHR_P...
# 387  https://www.intimissimi.com/dw/image/v2/BHHR_P...
#
# [374 rows x 1 columns]

# %%
intimissimi['precio']
# Out:
# 0      € 29,90
# 1      € 29,90
# 2      € 29,90
# 3      € 29,90
# 4      € 35,90
#         ...
# 397    € 39,90
# 398    € 29,90
# 399    € 27,90
# 400    € 19,90
# 401    € 27,90
# Name: precio, Length: 388, dtype: object

# %%
sns.scatterplot(intimissimi['producto'],intimissimi['precio'], hue = intimissimi['colors'])
# Out:
# /home/fer/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='producto', ylabel='precio'>
